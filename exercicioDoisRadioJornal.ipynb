# %% [markdown]
# ##### Exercício para avaliar o impacto de cada uma das variáveis sobre o resultado
# #### Importação dos dados
# ----
# ###### Avaliando o impácto das variáveis Rádio e Jornal sobre o resultado

# %%
import pandas as pd
publi = pd.read_csv('dados/advertising.csv')
publi.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %% [markdown]
# ### Observações
# ###### Com todas as variáveis

# %%
x = publi[['Radio','Newspaper']]

# %% [markdown]
# ### Target
# Definiando qual coluna é o alvo

# %%
y = publi['Sales']

# %% [markdown]
# ### Separando os dados em treino e teste

# %%
from sklearn.model_selection import train_test_split
#random_state=5 faz com que mesmo que seja realizado um random ele mantenha os valores a cada execução
#com ele faremos os testes com os mesmos registros, mesmo removendo uma variável
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=5)

# %% [markdown]
# ### Importanto o modelo de regressão Linear

# %%
from sklearn.linear_model import LinearRegression
reglin = LinearRegression()

# %% [markdown]
# ### Rodando o modelo de regressão Linear

# %%
reglin.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Coefinetes de aumento nas vendas a cada 1 unidade investida em publicidade
#
# ###### A cada 1 unidade investido em publicidade na tv temos um aumento de 0.05
# ###### A cada 1 unidade investida em publicidade no rádio temos um aumento de 0.09

# %%
#A função zip do python serve para criar uma tupla formada pelos labels e pelos respecitivos coeficientes
list(zip(['Radio','Newspaper'], reglin.coef_))
# Out:
# [('Radio', 0.14057190175219314), ('Newspaper', 0.005019760860699735)]

# %% [markdown]
# ### Previsão

# %%
feature_names = ['Radio','Newspaper']
data_to_predict = pd.DataFrame([[37.8, 69.2]], columns=feature_names)
print(reglin.predict(data_to_predict))
# Out:
# [17.16929291]

# %%
y_prev = reglin.predict(x_test)
print(y_prev)
# Out:
# [13.86939866 15.58588737 17.23309036 15.23846971 14.52206242 12.9335739
#  11.9239884  16.23703033 15.43275863 13.67761218 13.48083012 11.74225446
#  12.34318865 14.80168542 18.75374517 16.35652853 17.60758312 16.96850061
#  11.69505755 17.26367929 11.91545853 15.69031328 15.63659254 12.41192776
#  18.29738939 17.00211069 12.0520109  17.35505753 15.66619611 17.72256726
#  12.09819456 17.87668322 15.41118482 16.86404681 12.11776419 12.87586896
#  12.0976963  13.64699164 16.36554364 13.37137515 14.26851429 13.82421152
#  16.90223791 14.82929782 14.01549044 17.25917452 14.18116487 13.97982968
#  14.20676565 17.23055445 16.4343404  11.66693759 12.82163323 14.85491348
#  18.26025432 13.07917486 14.41913873 13.03550666 17.78530869 16.69286553]

# %% [markdown]
# ### Avaliação do modelo
#
# ###### Como o modelo é regressão, ou seja prediz um valor, a forma de avaliar o desempenho é um pouco diferente do que foi feito antes na classificação, a avaliação será realizada com base no erro entre a classe real e a prevista

# %%
from sklearn import metrics

# %% [markdown]
# ### RMSE Root Mean Squared Error
# ##### Basicamente aplica uma raiz quadrada ao resultado do MSE

# %%
import numpy as np

# %%
rmse = np.sqrt(metrics.mean_squared_error(y_test, y_prev))
print(rmse)
# Out:
# 4.883915543206654
