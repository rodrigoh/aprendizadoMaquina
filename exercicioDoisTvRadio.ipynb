# %% [markdown]
# ##### Exercício para avaliar o impacto de cada uma das variáveis sobre o resultado
# #### Importação dos dados
# ----
# ###### Avaliando o impácto das variáveis Tv e Rádio sobre o resultado

# %%
import pandas as pd
publi = pd.read_csv('dados/advertising.csv')
publi.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %% [markdown]
# ### Observações
# ###### Com todas as variáveis

# %%
x = publi[['TV','Radio']]

# %% [markdown]
# ### Target
# Definiando qual coluna é o alvo

# %%
y = publi['Sales']

# %% [markdown]
# ### Separando os dados em treino e teste

# %%
from sklearn.model_selection import train_test_split
#random_state=5 faz com que mesmo que seja realizado um random ele mantenha os valores a cada execução
#com ele faremos os testes com os mesmos registros, mesmo removendo uma variável
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=5)

# %% [markdown]
# ### Importanto o modelo de regressão Linear

# %%
from sklearn.linear_model import LinearRegression
reglin = LinearRegression()

# %% [markdown]
# ### Rodando o modelo de regressão Linear

# %%
reglin.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Coefinetes de aumento nas vendas a cada 1 unidade investida em publicidade
#
# ###### A cada 1 unidade investido em publicidade na tv temos um aumento de 0.05
# ###### A cada 1 unidade investida em publicidade no rádio temos um aumento de 0.09

# %%
#A função zip do python serve para criar uma tupla formada pelos labels e pelos respecitivos coeficientes
list(zip(['TV','Radio'], reglin.coef_))
# Out:
# [('TV', 0.05440341406347632), ('Radio', 0.10840175490850724)]

# %% [markdown]
# ### Previsão

# %%
feature_names = ['TV','Radio']
data_to_predict = pd.DataFrame([[230.1, 37.8]], columns=feature_names)
print(reglin.predict(data_to_predict))
# Out:
# [21.22946172]

# %%
y_prev = reglin.predict(x_test)
print(y_prev)
# Out:
# [ 7.40350412 14.25871122 11.04957027  9.8422477  17.117888   12.10703766
#  17.06017877 11.29742368 21.08690679 12.13728977 21.67981063  9.971819
#  18.08186926 18.0477003  20.78953556 21.29072324 17.33275952 21.10437438
#   8.85679205 10.80544353 13.41506902 15.5640691  22.02739723 17.73981638
#  19.5558743  22.22013046 17.08153507 24.21548002  8.05688405 20.89005418
#  19.29571351 14.43760673 23.58922079 18.98901324 15.81949738 11.11640943
#   7.09294672 13.73675015 20.20854088  9.36884462 13.77317174 19.312614
#   9.66337691 16.5787271  18.8659389  11.29479071 16.82532479 18.68685322
#  15.9603105   9.25482471 15.0614108   9.56423897 16.78029092 17.88952532
#  13.94119892 10.56681343  7.858832   20.95234416 23.45801684 12.49340763]

# %% [markdown]
# ### Avaliação do modelo (1)
#
# ###### Como o modelo é regressão, ou seja prediz um valor, a forma de avaliar o desempenho é um pouco diferente do que foi feito antes na classificação, a avaliação será realizada com base no erro entre a classe real e a prevista

# %%
from sklearn import metrics

# %% [markdown]
# ### RMSE Root Mean Squared Error
# ##### Basicamente aplica uma raiz quadrada ao resultado do MSE

# %%
import numpy as np

# %%
rmse = np.sqrt(metrics.mean_squared_error(y_test, y_prev))
print(rmse)
# Out:
# 1.3549049897062917
