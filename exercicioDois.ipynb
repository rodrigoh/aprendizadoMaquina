# %% [markdown]
# ##### Exercício para avaliar o impacto de cada uma das variáveis sobre o resultado
# #### Importação dos dados

# %%
import pandas as pd
publi = pd.read_csv('dados/advertising.csv')
publi.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %% [markdown]
# ### Observações
# ###### Com todas as variáveis

# %%
x = publi[['TV','Radio','Newspaper']]

# %% [markdown]
# ### Target
# Definiando qual coluna é o alvo

# %%
y = publi['Sales']

# %% [markdown]
# ### Separando os dados em treino e teste

# %%
from sklearn.model_selection import train_test_split
#random_state=5 faz com que mesmo que seja realizado um random ele mantenha os valores a cada execução
#com ele faremos os testes com os mesmos registros, mesmo removendo uma variável
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=5)

# %% [markdown]
# ### Importanto o modelo de regressão Linear

# %%
from sklearn.linear_model import LinearRegression
reglin = LinearRegression()

# %% [markdown]
# ### Rodando o modelo de regressão Linear (1)

# %%
reglin.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Coefinetes de aumento nas vendas a cada 1 unidade investida em publicidade
#
# ###### A cada 1 unidade investido em publicidade na tv temos um aumento de 0.05
# ###### A cada 1 unidade investida em publicidade no rádio temos um aumento de 0.09

# %%
#A função zip do python serve para criar uma tupla formada pelos labels e pelos respecitivos coeficientes
list(zip(['TV','Radio','Newspaper'], reglin.coef_))
# Out:
# [('TV', 0.05441361114174671),
#  ('Radio', 0.10909700436245226),
#  ('Newspaper', -0.0013875966328157213)]

# %% [markdown]
# ### Previsão

# %%
feature_names = ['TV','Radio','Newspaper']
data_to_predict = pd.DataFrame([[230.1, 37.8, 69.2]], columns=feature_names)
print(reglin.predict(data_to_predict))
# Out:
# [21.18672271]

# %%
y_prev = reglin.predict(x_test)
print(y_prev)
# Out:
# [ 7.40853843 14.28470661 11.08611981  9.85671235 17.14594651 12.07119154
#  17.06714091 11.31286158 21.10116502 12.12902057 21.71191275  9.98815589
#  18.0798832  18.04607711 20.76730919 21.33430087 17.30649968 21.11316303
#   8.86224678 10.76628599 13.43161238 15.59306926 22.0526923  17.65155915
#  19.53306079 22.17239817 17.09264513 24.19310937  8.0437044  20.89988211
#  19.29842546 14.42338986 23.63363129 18.93535384 15.80033509 11.14376817
#   7.10141574 13.73724507 20.2059376   9.37750292 13.76395234 19.31260504
#   9.68438463 16.57710233 18.86831748 11.28464307 16.82896336 18.65556976
#  15.9567102   9.23639296 15.0941714   9.55783302 16.77626414 17.9126916
#  13.95131782 10.54972978  7.87407314 20.95718473 23.43912285 12.47003672]

# %% [markdown]
# ### Avaliação do modelo
#
# ###### Como o modelo é regressão, ou seja prediz um valor, a forma de avaliar o desempenho é um pouco diferente do que foi feito antes na classificação, a avaliação será realizada com base no erro entre a classe real e a prevista

# %%
from sklearn import metrics

# %% [markdown]
# ### RMSE Root Mean Squared Error
# ##### Basicamente aplica uma raiz quadrada ao resultado do MSE

# %%
import numpy as np

# %%
rmse = np.sqrt(metrics.mean_squared_error(y_test, y_prev))
print(rmse)
# Out:
# 1.3570956388868882
